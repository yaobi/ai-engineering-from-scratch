# %%
print("Hello Jupyter")
# Out:
# Hello Jupyter

# %% [markdown]
# # JupyterLab 基础练习
#
# 这一节课练习代码单元格、Markdown 单元格、魔法命令、表格显示和图像绘制。

# %%
import numpy as np

data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.003791608390750923), np.float64(0.9902421215660644))

# %%
# %timeit [x ** 2 for x in range(100000)]
# Out:
# 3.25 ms ± 94.4 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
arr = np.arange(100000)
# %timeit arr ** 2
# Out:
# 30.3 μs ± 794 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})

df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
